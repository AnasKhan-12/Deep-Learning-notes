# %% [markdown]
# ## MLP NOTATION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Geometric Intuition

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <video width="560" height="315" controls>
#   <source src="videoMLP.mp4" type="video/mp4">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# Assigning weights to output of perceptrons:-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if u see its acting like a perceptron (graph on the right side)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Architecture---> How nodes are connected with each other.

# %% [markdown]
# 4 methods of changing achitecture:
# 1. Change number of perceptrons(nodes) in hidden layer
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Adding nodes in input
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Add nodes in output (multiclass classification)
#
# ![image.png](attachment:image.png)
#
# Probability on each output node decides whther its a dog/cat/human

# %% [markdown]
# 4. Add hidden layers (first we only increased nodes in a single hidden layer)
#
# ![image.png](attachment:image.png)
#
# Universal function approximator (koi bhi complex data dedo neural network ussy capture ker hi lyta ha provided that hidden layers are enough and training time is enough)

# %% [markdown]
# Forward Propogation
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Same goes for layer 2 and others
