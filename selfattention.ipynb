# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# no lstms used here...here self attention is used for parallel data handling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Self Attention

# %% [markdown]
# Word embeddings
#
# ![image.png](attachment:image.png)

# %% [markdown]
# yahan entry hoti ha Self attention ki....jo hmy static word embeddings sy dynamic embeddings bnaker dyty ha....which means it captures the context of the word
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is self attention: mechanism which captures the true contextual meaning of a word.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the number is similiaraity...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We need task specific embeddings e.g example of "piece of cake" translation would be cake ka tukra...
# also we need weights and biases so that our mechanism improves

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ab y 3 vectors ksy bnyngy: data ki base py data sy seekh ky

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Parallelism
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Wv and V

# %% [markdown]
# ### Scaling self attention

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# high variance causes vanishing gradient for small numbers...training bs baray numbers ki basis per hogi

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# our scaling factor is the dimension of key vector

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# to keep the variance of X as Var(X) rather than dVar(X) we need to divide by its dimension as proved above

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
