# %% [markdown]
# There is no one single vector passed from encoder to decoder🤡

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Encoder: The problem is that for big sentences.. we are putting too much load on our encoder and context vector will not be as much good.
# Decoder: The problem is it is static given time stamp aik fix word ka translation keryga... acha hojta ager ham dekh k paty ky kis word ki translation k liy konsa word zyda important ha or uski base py translate na ky pura sentence parhty phir translate kerty.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Alpha hamy y btata ha ky ksi particular timestep ka output decoder ki previous input py kitna depend keryga .......ya nahi ky encoder ky ussi timestep py kitna depend kerta ha

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ci is a vector containing weights for each timestep of encoder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Luong Attention

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# so instead of using ANN to get a function we simply use dot product which also defines similarity between two points/vectors and this save computations and very useful

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# is sy hmry ps zyda updated values ati hain
