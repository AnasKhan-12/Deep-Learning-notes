# %% [markdown]
# Its a time saving trick in which we save time by compromising our memory

# %% [markdown]
# Ham derivatives ka asnwer store kerlyty hain output layer waly (by memoization) to reduce complexity
