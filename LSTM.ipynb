# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The architecture is complex just to communicate LTM (Cell state) and STM (Hidden State)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ht and Ct are vectors whose dimensions will always be same (this is a rule which can never be broken)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Its size can be varied

# %% [markdown]
# ![image.png](attachment:image.png)
#
# In sbki dimensions same rehti hain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Yellow lables are neural network layers with multiple nodes.....and the number of nodes in each layer would also be the same

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
