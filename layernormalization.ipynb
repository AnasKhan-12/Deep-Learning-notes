# %% [markdown]
# Batch normalization cant work with sequence or self-attention

# %% [markdown]
# we have to send same numbers of words in multiple sentences in self attention so for that we do zero padding

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# due to so much zeroes batch normalization result of mean and s.d will not be the real one or actual one
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# so according to this the zeroes only affect there respective rows not others so thats why they have no impact on the whole dataset
#
# ![image.png](attachment:image.png)
