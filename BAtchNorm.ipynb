# %% [markdown]
# To improve speed of our neural network training .. fast trainin..(less epochs)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Internal Covariate Shift:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Covariate shift jo internal layers k ander hrha due to continous changing of weights during backpropagation thats why its called internal covariate shift
#
# ___Har layer ky end may (output) ko normalize kerdyty ho ensuring that mean is 0 and s.d is 1___

# %% [markdown]
# HOW
#
# * Mini-Batch GD
# * Layer by Layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# * Every neuron has its own gamma and beta parameter
# * Kabhi kabhi normalization ki zaroort nhi hota to isly gamma or beta parameter ha neron ko flexibility denny k liay ky ager nahi chahiy normalization to adjust it accordingly

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# * For every neuron we have 4 learnable parameters gamma,beta,mean,s.d

# %% [markdown]
# ![image.png](attachment:image.png)
