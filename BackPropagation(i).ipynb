# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Thy Why part? (gradient wla formula)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Concept of Gradient:
#
# ![image.png](attachment:image.png)
#
# We will calculate how much each weight contributed to the loss using derivatives, and update them starting from the output layer.
