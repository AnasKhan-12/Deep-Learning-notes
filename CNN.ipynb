# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Edges-> intensity change

# %% [markdown]
# Edge detection:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# it changes the values of filter according to its need thorugh back propogation ..... intialization is random

# %% [markdown]
# n* n ka image m*m ka filter to resultant matrix would be n-m+1 * n-m+1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# m* m*c img and n * n * c filter---> result = m-n+1 * m-n+1 (single channel)

# %% [markdown]
# if we increase the number of filter number of channels also increase

# %% [markdown]
# ---

# %% [markdown]
# ### Padding and Strides

# %% [markdown]
# Issues:-
#
# 1. Numbr of layers decraese from our img after applying filter or convolution.
# 2. Side waly numbers i.e first column and last column are not as much operated as other numbers.
#
# So this is solved py padding

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# now the output will be of the same dimension

# %% [markdown]
# Stride-> how we move our filter on our imge .. jo ham 1 pixel ka move kerwty hain ussy stride by 1 kahty hain 1 pixel agy ..then a tthe end of side 1 pixel nichy.....
#
# Why?\
# sometimes you need only high level features so you use strides to extract only those\
# to reduce computation

# %% [markdown]
# ---

# %% [markdown]
# ### Pooling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### LeNET 5 Architecture

# %% [markdown]
# A basic cnn architecture...isy chnge kerky hi different architectures bnty hain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ismy avg. pooling use hui hui ha

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### CNN Vs. ANN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# basic principle is kind of same .. not completely... esy ann ma har neuron ky weights values sy multiply hoty hain ..... kuch usi trhn filter ki trainable values or you can say weights ...hmri img ky values sy multiply hti hain just a bit different multiplication....and addition of bias is same

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The above point proves how computational cost decreases because number of trainable parameters remain same no mtter what is the size of our img however in ANN it increases
