# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Seq vs Non-Seq:-
#
# ![image.png](attachment:image.png)
#
# Plus speech (audio)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# previous timestamp ki value store kerta ha thats why sequence is maintained

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Also called encoder decoder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Problems

# %% [markdown]
# 1. Long Term Dependency

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Jitna bara data hga i.e jitny zyda timestamps to gradient calculation ma short term walon ka role zyda hga instead of the long term or the starting words/timestamps (maths behind it is vanishing gradient)(intuition=amir khan in gajni)
