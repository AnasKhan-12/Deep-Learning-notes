# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Self attention cannot capture multiple meanings or perspectives

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# same goes for bank

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# now this will capture multiple perspectives.. yahan 2 perspectives capture hongy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# end py wapis wahi dimesnion bnaty hain jo start ma thi by applying linear transformation.
# jo zyda useful perspective ha wo rkhty hain yn mixture of both (with the help of transformation)

# %% [markdown]
# ![image.png](attachment:image.png)
