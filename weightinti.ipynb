# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For relu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Intialize 0 sy kia phr sigmoid ma bhja or sigmoid ka derivative 0.5 hta ha
#
#
# ![image.png](attachment:image.png)
#
# Aik input ky weights baraber ho jyngy chahy ap jinty bhi neurons rkhlo hidden layer it will act s  asingle neuron...or non linearity capture na ho pygi will behave as a perceptron

# %% [markdown]
# Case 2:\
# Non-zero constant...\
# Phr wahi chz repeat hgi sigmoid wali i.e same weights cause only one neuron

# %% [markdown]
# CAse 3 Random Init but with very small number (0.001):\
# for tanh and sigmoid:\
# Doesnt work.. we face Vanishig GD\
# for relu VGD nhi ayga but convergence booht slow hga\
# ![image.png](attachment:image.png)
#
# Large means 0-1
