# %% [markdown]
# Self attention cannot maintain the sequence of words in a sentence.....RNN maintains the sequence

# %% [markdown]
# Solution: Positional Encoding

# %% [markdown]
# another problem

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we increase sine cosine pair for each pair of dimension and the next pair will have low frequency

# %% [markdown]
# Now positional encoding:
# 1. it will be a vector.
# 2. its dimensions would be same as embedding of the word.
# 3. then add the embedding and positional vector. so dimensions remain same.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# i is half of the embedding vector dimension

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
