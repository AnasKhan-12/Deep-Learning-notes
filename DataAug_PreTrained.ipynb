# %% [markdown]
# 1.Data generation\
# 2.Reduces overfitting

# %% [markdown]
# ---

# %% [markdown]
# ImageNET Dataset or database contains 14 million labelled imges

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Transfer Learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
