# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# context is maintained in compressed vector when the sentence becomes large context becomes difficult to maintain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# agr input ma 6 words hain to output ma 10 bhi hoskty hain...hamny input ko baraber kerna to seekha tha but not output

# %% [markdown]
# ### Training the architecture:

# %% [markdown]
# ![image.png](attachment:image.png)
