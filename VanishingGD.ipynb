# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# * Instead of using one hidden layer with 512 neurons use Multiple hidden layers wih fewer neurons to improve our model\
# * Shuru wly layers edges/lines identify kerty hain... beech wly shapes..end wly pura object or structure pattern\
# * kitny number of hidden layers pr ruk jna chahiy?.... -> Jb overfitting hony lg jayay ruk jao

# %% [markdown]
# ![image.png](attachment:image.png)
#
# * Number of neurons should be "Sufficieent" ...Zyada sy start kero or ager overfitting ho to kam kerdo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Early Stopping Concept in keras

# %% [markdown]
# epochs limit hjty hain

# %% [markdown]
# --------------

# %% [markdown]
# ### Normalization

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When maximum and minimum values are known we do normalization else standardization...... Always do scaling

# %% [markdown]
# -----

# %% [markdown]
# ### Dropout Layers (solving the problem of overfitting)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Regularization Video

# %% [markdown]
# ![image.png](attachment:image.png)
#
# L2
#
# ![image-2.png](attachment:image-2.png)
#
# Lemda is a hypermater.. value brhyngy to underfitting ki trf jyngy or 0 krdynygy to pura term 0 jhyga or cost function wahi ryga jo tha phly\
# L1 ma bs square khtm hojyga Wi wali term per sy \
#
# Biases are never added only weights or weights square

# %% [markdown]
# L2 regularization -> Weight decay

# %% [markdown]
# L1 ma bht saray weights zero hjty hn not in L2
