# %% [markdown]
# V.imp for improving the speed of training NN

# %% [markdown]
# Problem for GD:
# 1. Learning rate
# 2. Same learning rate for all weights
# 3. Local Minima
# 4. Saddle Point

# %% [markdown]
# ### Exponentially Weighted Moving Average:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# purany points ko kitna weightage derhy ho Beta py depend ker rha ha

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <video width="560" height="315" controls>
#   <source src="sgd_with_mmnt.mp4" type="video/mp4">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# Beta or decay factor ko ap adjust kerskty ho...0.9 pa zyda oscillations thi 1 data per or 0.5 per perfect tha... os can be adjusted according to data

# %% [markdown]
# ---

# %% [markdown]
# ### NAG

# %% [markdown]
# WE damp the oscillations of momentum sgd

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Disadvantage
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Adam

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
