# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Same goes for GRU and LSTM...BiLSTM and BiGRU

# %% [markdown]
# ![image.png](attachment:image.png)
