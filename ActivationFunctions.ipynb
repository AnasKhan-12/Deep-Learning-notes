# %% [markdown]
# Its a gate between input and output.\
# It decides whether a neuron would be activated or not and if activated then how much activated?

# %% [markdown]
# Why need it?\
# Ager activation function nhi hga to hmry network non-linear data capture nhi kerpyga... it only capture linear data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tanh:\
# Adva: 1. Non-linear 2. Differentiable 3. Zero Centred (training faster than sigmoid)\
# Disadv: 1. Saturating func so causes Vanishing Grad  2. Computationally expensive

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# IT has one problem dying relu

# %% [markdown]
# ---

# %% [markdown]
# ### ReLU Variants Video

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Disadv disadv nahi ha... ky 0.01 hi kiun lyna ha (experimentally proven it is best)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# only disadvantage is computationally expensive

# %% [markdown]
# ![image.png](attachment:image.png)
#
# One big advantage is self normalization(mean=0,sd=1) which makes converges faster
