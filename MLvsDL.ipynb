# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ML -> Depends on Statistics
# DL -> Follows logic trys to mimic human brain
# Dono ka kam same ha -> input or output ky drmyan relationship find kerna

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# represntative learning -> feature extraction
# ML -> ma manually kerna prta ha
# DL-> ma automatically extract kerlyta ha algo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# interpretabillity is low in DL (we dont know why algorithm has taken such decision)
# while high in ML

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Perceptron:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * perceptron is just a line which divides dataset into regions.
# * Its a binary classifier can be used for regresion (apply linear activation function and MSE loss function)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Limitation: Only applies to Linear data or sort of linear data

# %% [markdown]
# ### Perceptron Loss

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# f(xi) is basically our predicted value oy y^

# %% [markdown]
# ![image.png](attachment:image.png)
