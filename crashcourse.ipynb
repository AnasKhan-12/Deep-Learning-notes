# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This happens for example if 1000 times that is how it will get trained or how you train a baby

# %% [markdown]
# ANN
# RNN
# CNN
# Object Detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# back propagation ma weight update asy hoti ha

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# creating neurons in hidden layers using dense
